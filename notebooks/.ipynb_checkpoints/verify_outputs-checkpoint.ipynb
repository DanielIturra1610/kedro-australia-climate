# %%
# Inicializar Kedro dentro del notebook
from kedro.framework.hooks import _create_hook_manager
from kedro.framework.context import KedroContext
from kedro.framework.project import configure_project, _get_project_metadata
from kedro.framework.session import KedroSession
from pathlib import Path
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:4                                                                                    │
# │                                                                                                  │
# │   1 # Inicializar Kedro dentro del notebook                                                      │
# │   2 from kedro.framework.hooks import _create_hook_manager                                       │
# │   3 from kedro.framework.context import KedroContext                                             │
# │ ❱ 4 from kedro.framework.project import configure_project, _get_project_metadata                 │
# │   5 from kedro.framework.session import KedroSession                                             │
# │   6 from pathlib import Path                                                                     │
# ...

# %%
# Ruta correcta al proyecto raíz
project_path = Path.cwd().parent

# %%
session = KedroSession.create(project_path=project_path)
context = session.load_context()
catalog = context.catalog
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/site-packages/kedro/io/core.py:395 in parse_dataset_definition         │
# │                                                                                                  │
# │   392 │   │                                                                                      │
# │   393 │   │   trials = (_load_obj(class_path) for class_path in class_paths)                     │
# │   394 │   │   try:                                                                               │
# │ ❱ 395 │   │   │   class_obj = next(obj for obj in trials if obj is not None)                     │
# │   396 │   │   except StopIteration as exc:                                                       │
# │   397 │   │   │   raise DataSetError(                                                            │
# ...

# %%
# Cargar un dataset y visualizar
df = catalog.load("cleaned_weather_data")
df.head()

# %%
# Output final: índice de riesgo climático
risk_summary = catalog.load("climate_risk_summary")
risk_summary.head()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 # Crea una sesión de Kedro                                                                   │
# │ ❱ 2 session = KedroSession.create(project_path)                                                  │
# │   3 context = session.load_context()                                                             │
# │   4                                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/site-packages/kedro/framework/session/session.py:194 in create         │
# ...
